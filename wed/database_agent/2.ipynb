# %%
pip install -U langchain-openai
# Out:
# ...
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.schema import HumanMessage
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-4o",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=1,
    api_key="sk-QHs76dJnRhccNr75CkO5vJcz2MjyW10LY6pTt39HBj1vaxYA",
    base_url="https://api.302.ai/v1",
)


llm.invoke("Translate this sentence from English "
    "to French and Spanish. I like red cars and "
    "blue houses, but my dog is yellow.")
# Out:
# AIMessage(content="In French: J'aime les voitures rouges et les maisons bleues, mais mon chien est jaune.\n\nIn Spanish: Me gustan los coches rojos y las casas azules, pero mi perro es amarillo.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 42, 'prompt_tokens': 31, 'total_tokens': 73, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-8a188015-919f-45b7-931f-f26d92c0e96b-0', usage_metadata={'input_tokens': 31, 'output_tokens': 42, 'total_tokens': 73, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
import os
import pandas as pd

os.makedirs("data", exist_ok=True)
# !wget https://covidtracking.com/data/download/all-states-history.csv -P ./data/
file_url = "./data/all-states-history.csv"
# 读取csv 数据到dataframe中 df 
# na Not a Number 缺失值 用0
df = pd.read_csv(file_url).fillna(value=0)
# Out:
# --2025-01-01 14:51:09--  https://covidtracking.com/data/download/all-states-history.csv
# 正在解析主机 covidtracking.com (covidtracking.com)... 104.21.64.114, 172.67.183.132
# 正在连接 covidtracking.com (covidtracking.com)|104.21.64.114|:443... 已连接。
# 已发出 HTTP 请求，正在等待回应... 200 OK
# 长度：未指定 [text/csv]
# 正在保存至: “./data/all-states-history.csv.3”
#
# all-states-history.     [      <=>           ]   2.61M  2.22MB/s  用时 1.2s
#
# 2025-01-01 14:51:22 (2.22 MB/s) - “./data/all-states-history.csv.3” 已保存 [2738601]

# %%
df.head()
# Out:
#          date state    death  deathConfirmed  deathIncrease  deathProbable  \
# 0  2021-03-07    AK    305.0             0.0              0            0.0
# 1  2021-03-07    AL  10148.0          7963.0             -1         2185.0
# 2  2021-03-07    AR   5319.0          4308.0             22         1011.0
# 3  2021-03-07    AS      0.0             0.0              0            0.0
# 4  2021-03-07    AZ  16328.0         14403.0              5         1925.0
#
#    hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 0        1293.0                  1293.0                   33.0
# 1       45976.0                 45976.0                  494.0
# 2       14926.0                 14926.0                  335.0
# 3           0.0                     0.0                    0.0
# 4       57907.0                 57907.0                  963.0
#
#    hospitalizedIncrease  ...  totalTestResults  totalTestResultsIncrease  \
# ...

# %%
os.makedirs("data", exist_ok=True)
# !wget https://covidtracking.com/data/download/all-states-history.csv -P ./data/
file_url = "./data/all-states-history.csv"
# 读取csv 数据到dataframe中 df 
# na Not a Number 缺失值 用0
df = pd.read_csv(file_url).fillna(value=0)
# Out:
# --2025-01-01 11:19:12--  https://covidtracking.com/data/download/all-states-history.csv
# 正在解析主机 covidtracking.com (covidtracking.com)... 172.67.183.132, 104.21.64.114
# 正在连接 covidtracking.com (covidtracking.com)|172.67.183.132|:443... 已连接。
# 已发出 HTTP 请求，正在等待回应... 200 OK
# 长度：未指定 [text/csv]
# 正在保存至: “./data/all-states-history.csv.2”
#
# all-states-history.     [      <=>           ]   2.61M  2.16MB/s  用时 1.2s
#
# 2025-01-01 11:19:14 (2.16 MB/s) - “./data/all-states-history.csv.2” 已保存 [2738601]

# %%
# !pip install langchain_experimental

# %%
pip show langchain
# Out:
# Name: langchain
# Version: 0.1.6
# Summary: Building applications with LLMs through composability
# Home-page: https://github.com/langchain-ai/langchain
# Author:
# Author-email:
# License: MIT
# Location: /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages
# Requires: aiohttp, dataclasses-json, jsonpatch, langchain-community, langchain-core, langsmith, numpy, pydantic, PyYAML, requests, SQLAlchemy, tenacity
# Required-by: langchain-experimental
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_experimental.agents.agent_toolkits import create_pandas_dataframe_agent
# Out:
# ---------------------------------------------------------------------------
# PydanticUserError                         Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 from langchain_experimental.agents.agent_toolkits import create_pandas_dataframe_agent
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/langchain_experimental/agents/__init__.py:1
# ----> 1 from langchain_experimental.agents.agent_toolkits import (
#       2     create_csv_agent,
#       3     create_pandas_dataframe_agent,
#       4     create_spark_dataframe_agent,
#       5     create_xorbits_agent,
#       6 )
#       8 __all__ = [
#       9     "create_csv_agent",
#      10     "create_pandas_dataframe_agent",
#      11     "create_spark_dataframe_agent",
#      12     "create_xorbits_agent",
#      13 ]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/langchain_experimental/agents/agent_toolkits/__init__.py:1
# ...
